# %%
# Dictionary

person = {
    "name" : "Bikash Chauhan",
    "age" : 22,
    "sex" : 'M'
}

colors = {
    "red" : "#ff0000",
    "blue" : "#0000ff",
    "green" : "#00ff00",
    "pink": "#e186ad"
}

colors.get("red")

marks = {
    "MATH" : 97,
    "ENGLISH" : 82,
    "PHYSICS" : 92,
    "CHEMISTRY": 82
    }

total = 0 

for key,val in marks.items():
  total += val

total

average = total/len(marks.items())
average
# Out:
# 88.25

# %%
for i in marks.keys():
  print(marks.get(i))
# Out:
# 97
# 82
# 92
# 82

# %%
marks.get("MATH")
# Out:
# 97

# %%
marks
# Out:
# {'MATH': 97, 'ENGLISH': 82, 'PHYSICS': 92, 'CHEMISTRY': 82}

# %%
marks['MATH'] = 98

# %%
marks
# Out:
# {'MATH': 98, 'ENGLISH': 82, 'PHYSICS': 92, 'CHEMISTRY': 82}

# %%
students = [
    {
        "name": "ABC",
        "marks": 
            {
              "MATH" : 97,
              "ENGLISH" : 81,
              "PHYSICS" : 87,
              "CHEMISTRY" : 90   
            }
    }, 

    {
        "name": "DEF",
        "marks": 
            {
              "MATH" : 57,
              "ENGLISH" : 82,
              "PHYSICS" : 84,
              "CHEMISTRY" : 91   
            }
    },

    {
        "name": "GHI",
        "marks": 
            {
              "MATH" : 92,
              "ENGLISH" : 61,
              "PHYSICS" : 77,
              "CHEMISTRY" : 99   
            }
    }
]


# Accessing dictionary nested dictionary
students[0]["marks"]["MATH"]
# Out:
# 97

# %%
lst = ['Hari', 'Dev', 'Saumya', 'Shivam', 'Hari']
lst[1:4]
# Out:
# ['Dev', 'Saumya', 'Shivam']

# %%
lst[3:]
# Out:
# ['Shivam', 'Hari']

# %%
lst[-2:]
# Out:
# ['Shivam', 'Hari']

# %%
del lst

# %%
num = 1011111111
isPrime = True

factors = []

for i in range(2, num):
  if num % i == 0:
    factors.append(i)
    isPrime = False

if isPrime:
  print("Prime")
else:
  print("Not prime")

print(f"The factors of {num} are: {factors}")
# Out:
# Not prime
# The factors of 1011111111 are: [3, 9, 89, 267, 801, 1262311, 3786933, 11360799, 112345679, 337037037]

# %%
age = int(input('Enter your age:'))

if age >= 18:
  print("You are an adult!")
else:
  print("You are not an adult!")
# Out:
# Enter your age:12
# You are not an adult!

# %%
# Generate all the prime numbers from 1 to num
num = 10000
primeNums = []
for i in range(1, num+1):
  isPrime = True
  for j in range(2, i):
    if i % j == 0:
      isPrime = False
      break

  if isPrime:
    primeNums.append(i)

# %%
import random
# Generate random prime numbers
primeNums[random.randint(0, len(primeNums))]
# Out:
# 8893

# %%
# Functions

def generatePrimeNums(num):
  primeNums = []
  for i in range(1, num+1):
    isPrime = True
    for j in range(2, i):
      if i % j == 0:
        isPrime = False
        break

    if isPrime:
      primeNums.append(i)
  
  return primeNums

generatePrimeNums(12)
# Out:
# [1, 2, 3, 5, 7, 11]

# %%
def writeOut():
  # Pass is used to indicate that work is not completed yet
  # in future we might add code at this point.
  # without 'pass' it leads to error
  # hence, error bypass with the help of 'pass' keyword
  pass


writeOut()

# %%
a = lambda x,y : x*y
a(2,4)
# Out:
# 8

# %%
b = lambda x,y,z : x+y+z
b(2,4,5)
# Out:
# 11

# %%
# Lambda function with argument as function
b = lambda x,y : y(x) # here y is function

c = lambda z : 2**z  

b(4,c)
# Out:
# 16

# %%
# List comprehension

nums = [1, 3, 4, 5, 6, 7, 8, 9, 10]
oddNums = ['Odd' if i%2!=0 else 'Even' for i in nums]
oddNums
# Out:
# ['Odd', 'Odd', 'Even', 'Odd', 'Even', 'Odd', 'Even', 'Odd', 'Even']
