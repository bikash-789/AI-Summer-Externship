# %% [markdown]
# <a href="https://colab.research.google.com/github/bikash-789/AI-Summer-Externship/blob/main/AI_DAY_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Import dataset
df = pd.read_csv("./drive/MyDrive/insurance.csv")
df
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
df.tail()
# Out:
#       age     sex    bmi  children smoker     region     charges
# 1333   50    male  30.97         3     no  northwest  10600.5483
# 1334   18  female  31.92         0     no  northeast   2205.9808
# 1335   18  female  36.85         0     no  southeast   1629.8335
# 1336   21  female  25.80         0     no  southwest   2007.9450
# 1337   61  female  29.07         0    yes  northwest  29141.3603

# %%
df.shape # (1338, 7) -> 1338 records and 7 features
# Out:
# (1338, 7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
# Check for missing values in any of feature
df.isnull().any()
# Out:
# age         False
# sex         False
# bmi         False
# children    False
# smoker      False
# region      False
# charges     False
# dtype: bool

# %%
# Check for how many null values in the particular feature
df.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
# If the data is following Normal Distribution we can replace any null values with Mean
# Else, we can use Median 
# The distribution can be found with the help of plot

# If we have null values in the categorical feature, we can fill it with Mode value

df['age'].fillna(df['age'].median(), inplace=True)
df['smoker'].fillna(df['smoker'].mode(), inplace=True)

# %%
# Descriptive statistics
df.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %%
df.region.unique()
# Out:
# array(['southwest', 'southeast', 'northwest', 'northeast'], dtype=object)

# %%
df.sex.unique()
# Out:
# array(['female', 'male'], dtype=object)

# %%
df.smoker.unique()
# Out:
# array(['yes', 'no'], dtype=object)

# %%
df.smoker.value_counts()
# Out:
# no     1064
# yes     274
# Name: smoker, dtype: int64

# %%
df.region.value_counts()
# Out:
# southeast    364
# southwest    325
# northwest    325
# northeast    324
# Name: region, dtype: int64

# %%
# Correlation - The relation between features
df.corr()
# Out:
# <ipython-input-28-59b3af79975c>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                age       bmi  children   charges
# age       1.000000  0.109272  0.042469  0.299008
# bmi       0.109272  1.000000  0.012759  0.198341
# children  0.042469  0.012759  1.000000  0.067998
# charges   0.299008  0.198341  0.067998  1.000000

# %%
# Univaritate - one variable
# Bivariate - two variable 
# Multivariate - more than two variable

sns.distplot(df.bmi)
# Out:
# <ipython-input-30-8c8c76c895c2>:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.bmi)
# <Axes: xlabel='bmi', ylabel='Density'>

# %%
plt.pie(df.smoker.value_counts(), [0.1,0], labels=['No', 'Yes']);

# %%
plt.pie(df.smoker.value_counts(), [0.1,0], labels=['No', 'Yes'],autopct="%1.1f%%", colors=['red', 'yellow'], shadow=True);

# %%
sns.barplot(x=df.region.value_counts().index, y=df.region.value_counts());

# %% [markdown]
# #Bivariate analysis

# %%
sns.lineplot(x=df.age, y=df.charges);

# %%
sns.scatterplot(x=df.bmi, y=df.charges);

# %%
# Multivariate analysis - more than two columns relationship\

sns.heatmap(df.corr());
# Out:
# <ipython-input-42-84e465fb4ef5>:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr());

# %%
sns.pairplot(df);

# %% [markdown]
# # Outlier Detection
# ## Detect the data points that deviate significantly from the majority of the data

# %%
# Z score, Percentile, IQR - removal method

sns.boxplot(df.bmi);

# %%
q1 = df.bmi.quantile(0.25)
q3 = df.bmi.quantile(0.75)

# %%
q1, q3
# Out:
# (26.29625, 34.69375)

# %%
upperlimit = q3 + 1.5 * (q3 - q1)
lowerlimit = q1 - 1.5 * (q3-q1)

upperlimit, lowerlimit
# Out:
# (47.290000000000006, 13.7)

# %%
# Now remove all the data with the bmi value greater than 'upperlimit'

condition = df['bmi'] > upperlimit
condition
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1333    False
# 1334    False
# 1335    False
# 1336    False
# 1337    False
# Name: bmi, Length: 1338, dtype: bool

# %%
filtered_df = df[~condition]
sns.boxplot(filtered_df.bmi)
# Out:
# <Axes: >

# %%
p99 = df.bmi.quantile(0.99)
p99
# Out:
# 46.40789999999996

# %%
filtered_data = df['bmi'] < p99
filtered_data
filtered_df = df[filtered_data]
filtered_df
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1324 rows x 7 columns]

# %%
sns.boxplot(filtered_df.bmi)
# Out:
# <Axes: >

# %%
# Z score

from scipy import stats

bmi_zscore = stats.zscore(df.bmi)
bmi_zscore
# Out:
# 0      -0.453320
# 1       0.509621
# 2       0.383307
# 3      -1.305531
# 4      -0.292556
#           ...
# 1333    0.050297
# 1334    0.206139
# 1335    1.014878
# 1336   -0.797813
# 1337   -0.261388
# Name: bmi, Length: 1338, dtype: float64

# %%
df_z = df['bmi'] < (np.abs(bmi_zscore) <= 3)
df_z
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1334 rows x 7 columns]

# %%
sns.boxplot(df_z.bmi)
# Out:
# <Axes: >
